# %%
# built-in imports
import importlib

# external imports
import xarray as xr
import HydroErr as he
import numexpr as ne

# %%
# there are 3 parts to model executation
output_path = '/Users/kasrakeshavarz/Downloads/test/' # user input to FIAT
date_start = '1982-01-01 00:00:00' # user input to FIAT: fiat.Calibration.dates.start
date_end = '2000-12-31 23:00:00' # user input to FIAT: fiat.Calibration.dates.end
objective_functions = {
    'QO': {
        'kge_2012': ['-1 * station_1', '-1 * station_2', '(-0.5 * station_1) + (-0.5 * station_2)'],
        'nse': ['(-0.75 * station_1) + (-0.25 * station_2)', 'sin(station_1) + cos(station_2)'],
    },
} # user input to FIAT: fiat.Calibration.objective_functions

# 1. pre-process
# 1.1 necessary paths (can be hard-coded)
model_instance_path = '../../model/' # can be hard-coded as it will be standard
fiat_instance_path = os.path.join(output_path) # can be hard-coded as it will be standard
observations_path = os.path.join(fiat_instance_path, 'observations', 'obs.nc') # ditto

# 1.2 necessary calibration configurations
start_date = date_start
end_date = date_end

# 1.3 necessary information on objective functions
objective_functions = 

# 1.4 read necessary files
observations = xr.open_dataset(observations_path)

# 2. run
